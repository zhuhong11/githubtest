# %%
from obspy import read, UTCDateTime
import matplotlib.pyplot as plt
# Out:
# /home/zhu/miniconda3/envs/obspy-1/lib/python3.10/site-packages/obspy-0.0.0+archive-py3.10-linux-x86_64.egg/obspy/core/util/version.py:156: UserWarning: ObsPy could not determine its version number. Make sure it is properly installed. This for example happens when installing from a zip archive of the ObsPy repository which is not a supported way of installing ObsPy.
#   warnings.warn("ObsPy could not determine its version number. Make "

# %%
 # %%time
st = read('/home/zhu/pse.a11.1.1')
# Out:
# CPU times: user 1min 1s, sys: 430 ms, total: 1min 1s
# Wall time: 1min 1s

# %%
st_spz = st.select(id='XA.S11..SPZ')

# %%
st_spz
# Out:
# 487 Trace(s) in Stream:
#
# XA.S11..SPZ | 1969-07-21T04:39:22.788000Z - 1969-07-21T04:39:34.240830Z | 53.0 Hz, 608 samples
# ...
# (485 other traces)
# ...
# XA.S11..SPZ | 1969-07-22T07:29:48.941000Z - 1969-07-22T08:21:25.676849Z | 53.0 Hz, 164128 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]

# %%
st_spz.plot(starttime=UTCDateTime('1969-07-21T04:35:00'), endtime=UTCDateTime('1969-07-21T04:50:00'))
plt.show()

# %%
st_spz.plot(starttime=UTCDateTime('1969-07-21T04:35:00'), endtime=UTCDateTime('1969-07-21T04:50:00'))

# %%
type(st_spz)
# Out:
# obspy.core.stream.Stream

# %%
a=st_spz.plot(starttime=UTCDateTime('1969-07-21T04:35:00'), endtime=UTCDateTime('1969-07-21T04:50:00'))

# %%
a

# %%
st_spz[0]
# Out:
# XA.S11..SPZ | 1969-07-21T04:39:22.788000Z - 1969-07-21T04:39:34.240830Z | 53.0 Hz, 608 samples

# %%
st_spz(1969-07-21T04:39:22.788000Z - 1969-07-21T04:39:34.240830Z)
# Out:
#   Input In [31]
#     st_spz(1969-07-21T04:39:22.788000Z - 1969-07-21T04:39:34.240830Z)
#                 ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %%
st_spz(starttime=UTCDateTime('1969-07-21T04:35:00'), endtime=UTCDateTime('1969-07-21T04:50:00'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [32], in <cell line: 1>()
# ----> 1 st_spz(starttime=UTCDateTime('1969-07-21T04:35:00'), endtime=UTCDateTime('1969-07-21T04:50:00'))
#
# TypeError: 'Stream' object is not callable

# %%
st_spz=(UTCDateTime='1969-07-21T04:39:22.788000Z - 1969-07-21T04:39:34.240830Z')
# Out:
#   Input In [34]
#     st_spz=(UTCDateTime='1969-07-21T04:39:22.788000Z - 1969-07-21T04:39:34.240830Z')
#             ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?
